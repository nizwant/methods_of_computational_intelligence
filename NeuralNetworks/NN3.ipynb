# %%
import sys
import os
sys.path.insert(1, os.path.join(sys.path[0], 'code/implementation'))

# %%
import neural_network as nn
import layer as layer 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # square-large (MSE: 1)

# %%
square_large_train = pd.read_csv(
    "https://raw.githubusercontent.com/nizwant/miowid/main/data/regression/square-large-training.csv",
    index_col=0,
)
square_large_test = pd.read_csv(
    "https://raw.githubusercontent.com/nizwant/miowid/main/data/regression/square-large-test.csv",
    index_col=0,
)

# %%
mean = square_large_train.mean()
std = square_large_train.std()
square_large_train = (square_large_train - mean) / std
square_large_test = (square_large_test - mean) / std

# %%
plt.scatter(square_large_train.x, square_large_train.y, label="train")
plt.scatter(square_large_test.x, square_large_test.y, label="test")

# %%
neural = nn.NeuralNetwork([10], 1, 1)
mse, mse_after_epoch = neural.adam(
    square_large_train["x"],
    square_large_train["y"],
    learning_rate=0.001,
    batch_size=25,
    max_num_epoch=5000,
    silent=True,
)
neural.mean_squared_error(square_large_test["x"], square_large_test["y"]) * std[
    "y"
] ** 2
# Out:
# 3.632052527875267

# %%
plt.plot(mse)
plt.title("Mean Squared Error")
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Out:
# Text(0, 0.5, 'MSE')

# %% [markdown]
# ## Test

# %%
y = []
for i in square_large_test["x"]:
    y.append(neural.forward(i))
plt.scatter(square_large_test["x"], y, c="red")
plt.scatter(square_large_test["x"], square_large_test["y"], c="blue")
plt.legend(["Prediction", "True"])
neural.mean_squared_error(square_large_test["x"], square_large_test["y"]) * std[
    "y"
] ** 2
# Out:
# 3.632052527875267

# %% [markdown]
# ## Train

# %%
y = []
for i in square_large_train["x"]:
    y.append(neural.forward(i))
plt.scatter(square_large_train["x"], y, c="red")
plt.scatter(square_large_train["x"], square_large_train["y"], c="blue")
plt.legend(["Prediction", "True"])
neural.mean_squared_error(square_large_train["x"], square_large_train["y"]) * std[
    "y"
] ** 2
# Out:
# 0.010447900497060267

# %% [markdown]
# # steps-large (MSE: 3)

# %%
steps_large_train = pd.read_csv(
    "https://raw.githubusercontent.com/nizwant/miowid/main/data/regression/steps-large-training.csv",
    index_col=0,
)
steps_large_test = pd.read_csv(
    "https://raw.githubusercontent.com/nizwant/miowid/main/data/regression/steps-large-test.csv",
    index_col=0,
)

# %%
mean = steps_large_train.mean()
std = steps_large_train.std()
steps_large_train = (steps_large_train - mean) / std
steps_large_test = (steps_large_test - mean) / std

# %%
plt.scatter(steps_large_train.x, steps_large_train.y, label="train")
plt.scatter(steps_large_test.x, steps_large_test.y, label="test")

# %%
neural = nn.NeuralNetwork([5,5], 1, 1)
mse, mse_after_epoch = neural.adam(
    steps_large_train["x"],
    steps_large_train["y"],
    learning_rate=0.1,
    batch_size=20,
    max_num_epoch=60,
    silent=True,
)
neural.mean_squared_error(steps_large_test["x"], steps_large_test["y"]) * std["y"] ** 2
# Out:
# 21.881155072124635

# %%
plt.plot(mse_after_epoch)
plt.title("Mean Squared Error")
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Out:
# Text(0, 0.5, 'MSE')

# %% [markdown]
# ## Test

# %%
y = []
for i in steps_large_test["x"]:
    y.append(neural.forward(i))
plt.scatter(steps_large_test["x"], y, c="red")
plt.scatter(steps_large_test["x"], steps_large_test["y"], c="blue")
plt.legend(["Prediction", "True"])
neural.mean_squared_error(steps_large_test["x"], steps_large_test["y"]) * std["y"] ** 2
# Out:
# 12.818272936105124

# %% [markdown]
# ## Train

# %%
y = []
for i in steps_large_train["x"]:
    y.append(neural.forward(i))
plt.scatter(steps_large_train["x"], y, c="red")
plt.scatter(steps_large_train["x"], steps_large_train["y"], c="blue")
plt.legend(["Prediction", "True"])
neural.mean_squared_error(steps_large_train["x"], steps_large_train["y"]) * std[
    "y"
] ** 2
# Out:
# 16.550239585929845

# %% [markdown]
# ## training it more than once

# %%
# neural = nn.NeuralNetwork([10, 10], 1, 1)
mse, mse_after_epoch = neural.adam(
    steps_large_train["x"],
    steps_large_train["y"],
    learning_rate=0.001,
    batch_size=20,
    max_num_epoch=400,
    silent=True,
)
neural.mean_squared_error(steps_large_test["x"], steps_large_test["y"]) * std["y"] ** 2
# Out:
# 3.3747428385864433

# %%
y = []
for i in steps_large_train["x"]:
    y.append(neural.forward(i))
plt.scatter(steps_large_train["x"], y, c="red")
plt.scatter(steps_large_train["x"], steps_large_train["y"], c="blue")
plt.legend(["Prediction", "True"])
neural.mean_squared_error(steps_large_train["x"], steps_large_train["y"]) * std[
    "y"
] ** 2
# Out:
# 4.044309618870479

# %%
plt.plot(mse_after_epoch)
plt.title("Mean Squared Error")
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Out:
# Text(0, 0.5, 'MSE')

# %%
y = []
for i in steps_large_test["x"]:
    y.append(neural.forward(i))
plt.scatter(steps_large_test["x"], y, c="red")
plt.scatter(steps_large_test["x"], steps_large_test["y"], c="blue")
plt.legend(["Prediction", "True"])
neural.mean_squared_error(steps_large_test["x"], steps_large_test["y"]) * std["y"] ** 2
# Out:
# 3.3747428385864433

# %% [markdown]
# # multimodal-large (MSE: 9)

# %%
multimodal_large_train = pd.read_csv(
    "https://raw.githubusercontent.com/nizwant/miowid/main/data/regression/multimodal-large-training.csv"
)
multimodal_large_test = pd.read_csv(
    "https://raw.githubusercontent.com/nizwant/miowid/main/data/regression/multimodal-large-test.csv",
)

# %%
mean = multimodal_large_train.mean()
std = multimodal_large_train.std()
multimodal_large_train = (multimodal_large_train - mean) / std
multimodal_large_test = (multimodal_large_test - mean) / std

# %%
plt.scatter(multimodal_large_train.x, multimodal_large_train.y, label="train")
plt.scatter(multimodal_large_test.x, multimodal_large_test.y, label="test")

# %%
neural = nn.NeuralNetwork([10], 1, 1)
mse, mse_after_epoch = neural.adam(
    multimodal_large_train["x"],
    multimodal_large_train["y"],
    learning_rate=0.05,
    batch_size=40,
    max_num_epoch=600,
    silent=False,
)
neural.mean_squared_error(multimodal_large_test["x"], multimodal_large_test["y"]) * std[
    "y"
] ** 2
# Out:
# Epoch: 0
# Epoch: 1
# Epoch: 2
# Epoch: 3
# Epoch: 4
# Epoch: 5
# Epoch: 6
# Epoch: 7
# Epoch: 8
# Epoch: 9
# Epoch: 10
# Epoch: 11
# Epoch: 12
# Epoch: 13
# Epoch: 14
# Epoch: 15
# Epoch: 16
# Epoch: 17
# Epoch: 18
# Epoch: 19
# Epoch: 20
# Epoch: 21
# Epoch: 22
# Epoch: 23
# Epoch: 24
# Epoch: 25
# Epoch: 26
# Epoch: 27
# Epoch: 28
# Epoch: 29
# Epoch: 30
# Epoch: 31
# Epoch: 32
# Epoch: 33
# Epoch: 34
# Epoch: 35
# Epoch: 36
# Epoch: 37
# Epoch: 38
# Epoch: 39
# Epoch: 40
# Epoch: 41
# Epoch: 42
# Epoch: 43
# Epoch: 44
# Epoch: 45
# Epoch: 46
# Epoch: 47
# Epoch: 48
# Epoch: 49
# Epoch: 50
# Epoch: 51
# Epoch: 52
# Epoch: 53
# Epoch: 54
# Epoch: 55
# Epoch: 56
# Epoch: 57
# Epoch: 58
# Epoch: 59
# Epoch: 60
# Epoch: 61
# Epoch: 62
# Epoch: 63
# Epoch: 64
# Epoch: 65
# Epoch: 66
# Epoch: 67
# Epoch: 68
# Epoch: 69
# Epoch: 70
# Epoch: 71
# Epoch: 72
# Epoch: 73
# Epoch: 74
# Epoch: 75
# Epoch: 76
# Epoch: 77
# Epoch: 78
# Epoch: 79
# Epoch: 80
# Epoch: 81
# Epoch: 82
# Epoch: 83
# ...

# %%
plt.plot(mse)
plt.title("Mean Squared Error")
plt.xlabel("Epoch")
plt.ylabel("MSE")
# Out:
# Text(0, 0.5, 'MSE')

# %% [markdown]
# ## Test

# %%
y = []
for i in multimodal_large_test["x"]:
    y.append(neural.forward(i))
plt.scatter(multimodal_large_test["x"], y, c="red")
plt.scatter(multimodal_large_test["x"], multimodal_large_test["y"], c="blue")
plt.legend(["Prediction", "True"])
neural.mean_squared_error(multimodal_large_test["x"], multimodal_large_test["y"]) * std[
    "y"
] ** 2
# Out:
# 5.069612867313923

# %% [markdown]
# # Comparison of optimizer algorithms

# %%
square_large_train = pd.read_csv(
    "https://raw.githubusercontent.com/nizwant/miowid/main/data/regression/square-large-training.csv",
    index_col=0,
)
square_large_test = pd.read_csv(
    "https://raw.githubusercontent.com/nizwant/miowid/main/data/regression/square-large-test.csv",
    index_col=0,
)
mean = square_large_train.mean()
std = square_large_train.std()
square_large_train = (square_large_train - mean) / std
square_large_test = (square_large_test - mean) / std

# %%
neural_adam = nn.NeuralNetwork([10], 1, 1)
_, mse_after_epoch_adam = neural_adam.adam(
    square_large_train["x"],
    square_large_train["y"],
    learning_rate=0.01,
    batch_size=25,
    max_num_epoch=500,
    silent=True,
)
neural_adam.mean_squared_error(square_large_test["x"], square_large_test["y"]) * std[
    "y"
] ** 2
# Out:
# 35.20235813306737

# %%
neural_moment = nn.NeuralNetwork([10], 1, 1)
_, mse_after_epoch_moment = neural_moment.mini_batch_gradient_descent_with_momentum(
    square_large_train["x"],
    square_large_train["y"],
    learning_rate=0.01,
    batch_size=25,
    max_num_epoch=500,
    silent=True,
)
neural_moment.mean_squared_error(square_large_test["x"], square_large_test["y"]) * std[
    "y"
] ** 2
# Out:
# 85.40733116506185

# %%
neural_rms_prop = nn.NeuralNetwork([10], 1, 1)
_, mse_after_epoch_rms_prop = neural_rms_prop.rmsprop(
    square_large_train["x"],
    square_large_train["y"],
    learning_rate=0.01,
    batch_size=25,
    max_num_epoch=500,
    silent=True,
)
neural_rms_prop.mean_squared_error(
    square_large_test["x"], square_large_test["y"]
) * std["y"] ** 2
# Out:
# 38.75115376375825

# %%
neural_stochastic = nn.NeuralNetwork([10], 1, 1)
_, mse_after_epoch_stochastic = (
    neural_stochastic.mini_batch_gradient_descent(
        square_large_train["x"],
        square_large_train["y"],
        learning_rate=0.01,
        batch_size=2,
        max_num_epoch=500,
        silent=True,
    )
)
neural_stochastic.mean_squared_error(
    square_large_test["x"], square_large_test["y"]
) * std["y"] ** 2
# Out:
# 173.8755432064186

# %%
neural_mini_batch = nn.NeuralNetwork([10], 1, 1)
_, mse_after_epoch_mini_batch = neural_mini_batch.mini_batch_gradient_descent(
    square_large_train["x"],
    square_large_train["y"],
    learning_rate=0.01,
    batch_size=25,
    max_num_epoch=500,
    silent=True,
)
neural_mini_batch.mean_squared_error(
    square_large_test["x"], square_large_test["y"]
) * std["y"] ** 2
# Out:
# 496.1906657026511

# %%
neural_full_batch = nn.NeuralNetwork([10], 1, 1)
_, mse_after_epoch_full_batch = neural_full_batch.mini_batch_gradient_descent(
    square_large_train["x"],
    square_large_train["y"],
    learning_rate=0.1,
    batch_fraction=1.0,
    max_num_epoch=500,
    silent=True,
)
neural_full_batch.mean_squared_error(
    square_large_test["x"], square_large_test["y"]
) * std["y"] ** 2
# Out:
# 1027.031938057617

# %%
mse_after_epoch_adam = np.array(mse_after_epoch_adam) * std["y"] ** 2
mse_after_epoch_moment = np.array(mse_after_epoch_moment) * std["y"] ** 2
mse_after_epoch_rms_prop = np.array(mse_after_epoch_rms_prop) * std["y"] ** 2
mse_after_epoch_stochastic = np.array(mse_after_epoch_stochastic) * std["y"] ** 2
mse_after_epoch_mini_batch = np.array(mse_after_epoch_mini_batch) * std["y"] ** 2
mse_after_epoch_full_batch = np.array(mse_after_epoch_full_batch) * std["y"] ** 2

# %%
# Plotting
plt.plot(mse_after_epoch_adam, label="Adam")
plt.plot(mse_after_epoch_moment, label="Momentum")
plt.plot(mse_after_epoch_rms_prop, label="RMSProp")
plt.plot(mse_after_epoch_stochastic, label="Stochastic GD")
plt.plot(mse_after_epoch_mini_batch, label="Mini Batch GD")
plt.plot(mse_after_epoch_full_batch, label="Full Batch GD")
plt.title("Mean Squared Error on Square Large Dataset")
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.legend()

# %%
# Plotting
plt.plot(mse_after_epoch_adam[:40], label="Adam")
plt.plot(mse_after_epoch_moment[:40], label="Momentum")
plt.plot(mse_after_epoch_rms_prop[:40], label="RMSProp")
plt.plot(mse_after_epoch_stochastic[:40], label="Stochastic GD")
plt.plot(mse_after_epoch_mini_batch[:40], label="Mini Batch GD")
plt.plot(mse_after_epoch_full_batch[:40], label="Full Batch GD")
plt.title("Mean Squared Error in the first 40 epochs on Square Large Dataset")
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.legend()
